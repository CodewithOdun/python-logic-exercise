# %%
student_name , student_age = "Odun" , 15
print(f"my name is {student_name} , I am {student_age}")
# Out:
# my name is Odun , I am 15

# %%
import time
student_name = str(input("Enter your name$"))
student_age = int(input("Enter your age$"))
print("loading.....")
time.sleep (2)
print(f"Your name is {student_name} , And you are {student_age}")
time.sleep(1)
print("Age compartibility verification")
time.sleep(3)
print("checking ... ! , Age compartibility verification")
time.sleep(5)
if student_age >= 16:
    print("You are eligible in the poll")
else:
    print("You are not eligible in the poll")
# Out:
# Enter your name$ Ayo
# Enter your age$ 12
# loading.....
# Your name is Ayo , And you are 12
# Age compartibility verification
# checking ... ! , Age compartibility verification
# You are not eligible in the poll
